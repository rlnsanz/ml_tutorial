# %%
import flor
flor.utils.latest(flor.dataframe("seed", "lr", "loss", "accuracy", "device"))
# Out:
#          projid              tstamp  filename  epoch epoch_value  step  \
# 0   ml_tutorial 2024-03-04 14:53:30  train.py      1           0   500
# 1   ml_tutorial 2024-03-04 14:53:30  train.py      1           0  1000
# 2   ml_tutorial 2024-03-04 14:53:30  train.py      1           0  1500
# 3   ml_tutorial 2024-03-04 14:53:30  train.py      1           0   500
# 4   ml_tutorial 2024-03-04 14:53:30  train.py      1           0  1000
# ..          ...                 ...       ...    ...         ...   ...
# 70  ml_tutorial 2024-03-04 14:53:30  train.py      5           4  1000
# 71  ml_tutorial 2024-03-04 14:53:30  train.py      5           4  1500
# 72  ml_tutorial 2024-03-04 14:53:30  train.py      5           4   500
# 73  ml_tutorial 2024-03-04 14:53:30  train.py      5           4  1000
# 74  ml_tutorial 2024-03-04 14:53:30  train.py      5           4  1500
#
#           seed     lr                 loss accuracy device
# 0   2534407392  0.001   0.9460157752037048    71.71    mps
# 1   2534407392  0.001   1.0491496324539185    71.71    mps
# 2   2534407392  0.001    1.344419002532959    71.71    mps
# 3   2534407392  0.001   0.9460157752037048    71.71    mps
# 4   2534407392  0.001   1.0491496324539185    71.71    mps
# ..         ...    ...                  ...      ...    ...
# 70  2534407392  0.001   0.8980441093444824    71.71    mps
# 71  2534407392  0.001  0.24625436961650848    71.71    mps
# 72  2534407392  0.001   0.7146424055099487    71.71    mps
# 73  2534407392  0.001   0.8980441093444824    71.71    mps
# 74  2534407392  0.001  0.24625436961650848    71.71    mps
#
# [75 rows x 11 columns]

# %%
flor.dataframe()
# Out:
#         projid              tstamp  filename device        seed hidden epochs  \
# 0  ml_tutorial 2024-03-04 12:57:04  train.py    mps  3163843977    500      5
# 1  ml_tutorial 2024-03-04 13:06:57  train.py    mps   387873906    500      5
# 2  ml_tutorial 2024-03-04 13:20:13  train.py    mps   467469192    500      5
# 3  ml_tutorial 2024-03-04 13:21:48  train.py    mps  3166085648    500      5
# 4  ml_tutorial 2024-03-04 14:53:30  train.py    mps  2534407392    500      5
#
#   batch_size      lr print_every accuracy correct
# 0         32   0.001         500    92.55    9255
# 1         32   0.001         500    82.41    8241
# 2         32  0.0001         500     92.7    9270
# 3         32  0.0001         500    92.57    9257
# 4         32   0.001         500    71.71    7171

# %%
import flor
flor.dataframe("seed", "lr", "loss")

# %%
df
# Out:
#          projid              tstamp  filename  epoch epoch_value  step  \
# 0   ml_tutorial 2024-03-04 14:53:30  train.py      1           0   500
# 1   ml_tutorial 2024-03-04 14:53:30  train.py      1           0  1000
# 2   ml_tutorial 2024-03-04 14:53:30  train.py      1           0  1500
# 3   ml_tutorial 2024-03-04 14:53:30  train.py      1           0   500
# 4   ml_tutorial 2024-03-04 14:53:30  train.py      1           0  1000
# ..          ...                 ...       ...    ...         ...   ...
# 70  ml_tutorial 2024-03-04 14:53:30  train.py      5           4  1000
# 71  ml_tutorial 2024-03-04 14:53:30  train.py      5           4  1500
# 72  ml_tutorial 2024-03-04 14:53:30  train.py      5           4   500
# 73  ml_tutorial 2024-03-04 14:53:30  train.py      5           4  1000
# 74  ml_tutorial 2024-03-04 14:53:30  train.py      5           4  1500
#
#           seed     lr                 loss
# 0   2534407392  0.001   0.9460157752037048
# 1   2534407392  0.001   1.0491496324539185
# 2   2534407392  0.001    1.344419002532959
# 3   2534407392  0.001   0.9460157752037048
# 4   2534407392  0.001   1.0491496324539185
# ..         ...    ...                  ...
# 70  2534407392  0.001   0.8980441093444824
# 71  2534407392  0.001  0.24625436961650848
# 72  2534407392  0.001   0.7146424055099487
# 73  2534407392  0.001   0.8980441093444824
# 74  2534407392  0.001  0.24625436961650848
#
# [75 rows x 9 columns]

# %%
df.sort_values(by=['epoch', 'step'])
# Out:
#          projid              tstamp  filename  epoch epoch_value  step  \
# 0   ml_tutorial 2024-03-04 14:53:30  train.py      1           0   500
# 3   ml_tutorial 2024-03-04 14:53:30  train.py      1           0   500
# 6   ml_tutorial 2024-03-04 14:53:30  train.py      1           0   500
# 9   ml_tutorial 2024-03-04 14:53:30  train.py      1           0   500
# 12  ml_tutorial 2024-03-04 14:53:30  train.py      1           0   500
# ..          ...                 ...       ...    ...         ...   ...
# 62  ml_tutorial 2024-03-04 14:53:30  train.py      5           4  1500
# 65  ml_tutorial 2024-03-04 14:53:30  train.py      5           4  1500
# 68  ml_tutorial 2024-03-04 14:53:30  train.py      5           4  1500
# 71  ml_tutorial 2024-03-04 14:53:30  train.py      5           4  1500
# 74  ml_tutorial 2024-03-04 14:53:30  train.py      5           4  1500
#
#           seed     lr                 loss
# 0   2534407392  0.001   0.9460157752037048
# 3   2534407392  0.001   0.9460157752037048
# 6   2534407392  0.001   0.9460157752037048
# 9   2534407392  0.001   0.9460157752037048
# 12  2534407392  0.001   0.9460157752037048
# ..         ...    ...                  ...
# 62  2534407392  0.001  0.24625436961650848
# 65  2534407392  0.001  0.24625436961650848
# 68  2534407392  0.001  0.24625436961650848
# 71  2534407392  0.001  0.24625436961650848
# 74  2534407392  0.001  0.24625436961650848
#
# [75 rows x 9 columns]
